# %% [markdown]
# ## Twitter Analytics
#
# **Author:** Mubasser Kamal
#
# **Description:** Collects Twitter data in real-time for a defined period of time and saves them in a JSON formatted file.

# %%
# Import the necessary methods from tweepy library

import time
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
import os
import configparser

# %% [markdown]
# ### Settings
#
# Using the built-in Python module, ConfigParser, reading the **config.ini** file (located in the same folder)

# %%
config = configparser.ConfigParser()
config.read('config.ini')

access_token = config['SETTINGS']['ACCESS_TOKEN']
access_token_secret = config['SETTINGS']['ACCESS_TOKEN_SECRET']
consumer_key = config['SETTINGS']['CONSUMER_KEY']
consumer_secret = config['SETTINGS']['CONSUMER_SECRET']

# %%
# setting a timer for how long to grab the tweets
start_time = time.time() #grabs the system time

# keywords/hashtags to track
keyword_list = ['fifa']

# %% [markdown]
# ### Listener class
#
# This class is a overridden class based on Tweepy's StreamListener class. We give it some initialization constructs to set the time limit for collecting the data.
#
# **on_data**: This definition is run when data is sent back by Twitter.
#
# **time_limit**: Time is based on seconds. The default value runs for a minute (60 seconds)

# %%
class StdOutListener(StreamListener):
    
    def __init__(self,time_limit=60,fname='tweet.json'):
        
        self.limit = time.time() + time_limit
        self.filename = fname
        self.tweet_data = []
        
    def on_data(self, data):
        
        # open a file to store the status objects
        file = open(self.filename, 'a')
        
        while (time.time() < self.limit):
            try:
                self.tweet_data.append(data)
                return True
            except BaseException as e:
                print('failed ondata,',str(e))
                time.sleep(5)
                pass

        # show progress
        print("Writing tweets")
        # write json to file
        file.write(data)
        return True

    def on_error(self, status):
        print(status)
        print('Error')
        return False


if __name__ == '__main__':
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    # There are different kinds of streams: public stream, user stream, multi-user streams
    # For more details refer to https://dev.twitter.com/docs/streaming-apis
    twitterStream = Stream(auth, StdOutListener(time_limit=20,fname='fifa.json'))
    #Hashtag to stream
    twitterStream.filter(track=keyword_list)
# Out:
# Writing tweets to file (1.542630910873413 seconds)
# Writing tweets to file (1.730130910873413 seconds)
# Writing tweets to file (1.890871286392212 seconds)
# Writing tweets to file (2.7080562114715576 seconds)
# Writing tweets to file (3.883002519607544 seconds)
# Writing tweets to file (4.5806849002838135 seconds)
# Writing tweets to file (4.736959457397461 seconds)
# Writing tweets to file (4.808129549026489 seconds)
# Writing tweets to file (5.3392722606658936 seconds)
# Writing tweets to file (5.4329674243927 seconds)
# Writing tweets to file (5.59174108505249 seconds)
# Writing tweets to file (6.528312921524048 seconds)
# Writing tweets to file (8.19715142250061 seconds)
# Writing tweets to file (8.38457202911377 seconds)
# Writing tweets to file (8.422820329666138 seconds)
# Writing tweets to file (8.430793523788452 seconds)
# Writing tweets to file (8.67166781425476 seconds)
# Writing tweets to file (8.873709201812744 seconds)
# Writing tweets to file (9.502300024032593 seconds)
# Writing tweets to file (9.56175971031189 seconds)
# Writing tweets to file (9.894603729248047 seconds)
# Writing tweets to file (10.935140371322632 seconds)
# Writing tweets to file (11.028890132904053 seconds)
# Writing tweets to file (11.192841529846191 seconds)
# Writing tweets to file (11.74738073348999 seconds)
# Writing tweets to file (11.93488335609436 seconds)
# Writing tweets to file (11.960417747497559 seconds)
# Writing tweets to file (13.515315055847168 seconds)
# Writing tweets to file (13.530895948410034 seconds)
# Writing tweets to file (13.907593965530396 seconds)
# Writing tweets to file (14.110719919204712 seconds)
# Writing tweets to file (15.052641868591309 seconds)
# Writing tweets to file (15.138087749481201 seconds)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# c:\users\pc6987hr\.virtualenvs\twitterminer-szau_eue\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# c:\users\pc6987hr\.virtualenvs\twitterminer-szau_eue\lib\site-packages\tweepy\streaming.py in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# c:\users\pc6987hr\.virtualenvs\twitterminer-szau_eue\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     314             length = 0
#     315             while not resp.raw.closed:
# --> 316                 line = buf.read_line().strip()
#     317                 if not line:
#     318                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# c:\users\pc6987hr\.virtualenvs\twitterminer-szau_eue\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# c:\users\pc6987hr\.virtualenvs\twitterminer-szau_eue\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# C:\Continuum\anaconda3\Lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# C:\Continuum\anaconda3\Lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# C:\Continuum\anaconda3\Lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# C:\Continuum\anaconda3\Lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# C:\Continuum\anaconda3\Lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# C:\Continuum\anaconda3\Lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# C:\Continuum\anaconda3\Lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# C:\Continuum\anaconda3\Lib\ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# C:\Continuum\anaconda3\Lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
